# %%
#-------------------------
# import packages
#-------------------------

import requests
import pycountry
import pandas as pd
import time  # for sleep/backoff

#--------------------------
# retrieve IMF trade data
#--------------------------

# get list of country codes 
country_codes = [country.alpha_2 for country in pycountry.countries]

# base API URL
base_url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/'

def get_imf_dots_data(reporter,
                      indicator='TXG_FOB_USD',
                      freq='Q',
                      startPeriod='1980',
                      endPeriod='2024',
                      max_retries=5,
                      backoff_factor=3):
    """
    Retrieve IMF DOTS data for a given reporter country, with basic retry logic.
    
    Parameters:
    -----------
    reporter : str
        ISO alpha-2 code for the reporter country (e.g., 'GB', 'US', 'CN', etc.)
    indicator : str
        IMF indicator code ('TMG_CIF_USD' for imports, 'TXG_FOB_USD' for exports)
    freq : str
        Frequency ('A' for annual, 'Q' for quarterly, 'M' for monthly)
    startPeriod : str
        Starting period (e.g., '1947')
    endPeriod : str
        Ending period (e.g., '2024')
    max_retries : int
        Maximum number of retry attempts for transient errors
    backoff_factor : int or float
        Multiplier for the backoff (sleep time) between retries
    
    Returns:
    --------
    data : dict or list or None
        Parsed JSON series data, or None if we can't retrieve valid data.
    """
    # construct the key - here, partner is omitted to retrieve all partners
    key = f'CompactData/DOT/{freq}.{reporter}.{indicator}'
    # remove extra space around startPeriod
    full_url = f'{base_url}{key}?startPeriod={startPeriod}&endPeriod={endPeriod}'
    
    for attempt in range(max_retries):
        print(f"Attempt {attempt+1} for {reporter}: {full_url}")
        try:
            # make the request
            response = requests.get(full_url, headers={"Accept": "application/json"}, timeout=30)
            
            # if the response code is not 200, raise for status
            # (this will trigger the except block to handle it)
            response.raise_for_status()
            
            # try to parse the JSON
            json_data = response.json()
            
            # navigate into the JSON to extract the series element
            data = json_data['CompactData']['DataSet']['Series']
            return data

        except requests.exceptions.RequestException as e:
            # for network issues or non-200 status codes
            # if it's the last attempt, return None
            if attempt == max_retries - 1:
                print(f"Final network error (no more retries) for {reporter}: {e}")
                return None
            else:
                # otherwise, wait before retrying
                wait_seconds = backoff_factor * (attempt + 1)
                print(f"Network error for {reporter}, retrying in {wait_seconds} seconds: {e}")
                time.sleep(wait_seconds)
        
        except KeyError as e:
            # if the JSON structure is missing expected keys,
            # don't retry because if the data truly doesn't exist, just return None
            print(f"JSON structure error (missing keys) for {reporter}: {e}")
            return None
        
        except ValueError as e:
            # JSON parsing error
            # possibly a rate-limiting or server error returning invalid JSON
            if attempt == max_retries - 1:
                print(f"Final JSON parse error for {reporter}: {e}")
                return None
            else:
                wait_seconds = backoff_factor * (attempt + 1)
                print(f"JSON parse error for {reporter}, retrying in {wait_seconds} seconds: {e}")
                time.sleep(wait_seconds)
    
    # if all attempts fail for some reason, return None
    return None

# list of reporter country codes you want to retrieve data for
reporters = country_codes  # adjust this list as needed

# dictionary to store the results
data_dict = {}

for rep in reporters:
    print(f"\nFetching data for {rep}...")
    series_data = get_imf_dots_data(rep)
    if series_data is not None:
        data_dict[rep] = series_data
    else:
        print(f"No data returned (or could not retrieve) for {rep}.")

#--------------------------------
# format data as table and save
#--------------------------------

records = []

for rep, series in data_dict.items():
    if isinstance(series, list):
        for s in series:
            cp = s.get('@COUNTERPART_AREA')
            obs = s.get('Obs')
            if isinstance(obs, list):
                for o in obs:
                    records.append({
                        'reporter': rep,
                        'counterpart_area': cp,
                        'time_period': o.get('@TIME_PERIOD'),
                        'value': o.get('@OBS_VALUE')
                    })
            elif isinstance(obs, dict):
                records.append({
                    'reporter': rep,
                    'counterpart_area': cp,
                    'time_period': obs.get('@TIME_PERIOD'),
                    'value': obs.get('@OBS_VALUE')
                })
    elif isinstance(series, dict):
        cp = series.get('@COUNTERPART_AREA')
        obs = series.get('Obs')
        if isinstance(obs, list):
            for o in obs:
                records.append({
                    'reporter': rep,
                    'counterpart_area': cp,
                    'time_period': o.get('@TIME_PERIOD'),
                    'value': o.get('@OBS_VALUE')
                })
        elif isinstance(obs, dict):
            records.append({
                'reporter': rep,
                'counterpart_area': cp,
                'time_period': obs.get('@TIME_PERIOD'),
                'value': obs.get('@OBS_VALUE')
            })

df = pd.DataFrame(records)
df['time_period'] = pd.to_datetime(df['time_period'], errors='coerce')

df.to_csv("../../data/raw/imf_exports_quarterly.csv", index=False)
# Out:
# Fetching data for AW...
# Attempt 1 for AW: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AW.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AF...
# Attempt 1 for AF: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AF.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AO...
# Attempt 1 for AO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AI...
# Attempt 1 for AI: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AI.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AX...
# Attempt 1 for AX: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AX.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for AX: 'Series'
# No data returned (or could not retrieve) for AX.
#
# Fetching data for AL...
# Attempt 1 for AL: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AL.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AD...
# Attempt 1 for AD: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AD.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for AD: 'Series'
# No data returned (or could not retrieve) for AD.
#
# Fetching data for AE...
# Attempt 1 for AE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AR...
# Attempt 1 for AR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AM...
# Attempt 1 for AM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AS...
# Attempt 1 for AS: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AS.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AQ...
# Attempt 1 for AQ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AQ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for AQ: 'Series'
# No data returned (or could not retrieve) for AQ.
#
# Fetching data for TF...
# Attempt 1 for TF: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TF.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for TF: 'Series'
# No data returned (or could not retrieve) for TF.
#
# Fetching data for AG...
# Attempt 1 for AG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AU...
# Attempt 1 for AU: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AU.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AT...
# Attempt 1 for AT: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AT.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for AZ...
# Attempt 1 for AZ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.AZ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BI...
# Attempt 1 for BI: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BI.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BE...
# Attempt 1 for BE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BJ...
# Attempt 1 for BJ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BJ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BQ...
# Attempt 1 for BQ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BQ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for BQ: 'Series'
# No data returned (or could not retrieve) for BQ.
#
# Fetching data for BF...
# Attempt 1 for BF: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BF.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BD...
# Attempt 1 for BD: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BD.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BG...
# Attempt 1 for BG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BH...
# Attempt 1 for BH: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BH.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BS...
# Attempt 1 for BS: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BS.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BA...
# Attempt 1 for BA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BL...
# Attempt 1 for BL: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BL.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for BL: 'Series'
# No data returned (or could not retrieve) for BL.
#
# Fetching data for BY...
# Attempt 1 for BY: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BY.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BZ...
# Attempt 1 for BZ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BZ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BM...
# Attempt 1 for BM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BO...
# Attempt 1 for BO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BR...
# Attempt 1 for BR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BB...
# Attempt 1 for BB: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BB.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BN...
# Attempt 1 for BN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BT...
# Attempt 1 for BT: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BT.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for BV...
# Attempt 1 for BV: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BV.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for BV: 'Series'
# No data returned (or could not retrieve) for BV.
#
# Fetching data for BW...
# Attempt 1 for BW: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.BW.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CF...
# Attempt 1 for CF: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CF.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CA...
# Attempt 1 for CA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CC...
# Attempt 1 for CC: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CC.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for CC: 'Series'
# No data returned (or could not retrieve) for CC.
#
# Fetching data for CH...
# Attempt 1 for CH: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CH.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CL...
# Attempt 1 for CL: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CL.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CN...
# Attempt 1 for CN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CI...
# Attempt 1 for CI: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CI.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CM...
# Attempt 1 for CM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CD...
# Attempt 1 for CD: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CD.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CG...
# Attempt 1 for CG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CK...
# Attempt 1 for CK: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CK.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for CK: 'Series'
# No data returned (or could not retrieve) for CK.
#
# Fetching data for CO...
# Attempt 1 for CO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for KM...
# Attempt 1 for KM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CV...
# Attempt 1 for CV: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CV.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CR...
# Attempt 1 for CR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CU...
# Attempt 1 for CU: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CU.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CW...
# Attempt 1 for CW: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CW.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CX...
# Attempt 1 for CX: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CX.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for CX: 'Series'
# No data returned (or could not retrieve) for CX.
#
# Fetching data for KY...
# Attempt 1 for KY: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KY.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for KY: 'Series'
# No data returned (or could not retrieve) for KY.
#
# Fetching data for CY...
# Attempt 1 for CY: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CY.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for CZ...
# Attempt 1 for CZ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.CZ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for DE...
# Attempt 1 for DE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.DE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for DJ...
# Attempt 1 for DJ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.DJ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for DM...
# Attempt 1 for DM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.DM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for DK...
# Attempt 1 for DK: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.DK.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for DO...
# Attempt 1 for DO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.DO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for DZ...
# Attempt 1 for DZ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.DZ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for EC...
# Attempt 1 for EC: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.EC.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for EG...
# Attempt 1 for EG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.EG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for ER...
# Attempt 1 for ER: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.ER.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for EH...
# Attempt 1 for EH: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.EH.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for EH: 'Series'
# No data returned (or could not retrieve) for EH.
#
# Fetching data for ES...
# Attempt 1 for ES: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.ES.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for EE...
# Attempt 1 for EE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.EE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for ET...
# Attempt 1 for ET: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.ET.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for FI...
# Attempt 1 for FI: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.FI.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for FJ...
# Attempt 1 for FJ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.FJ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for FK...
# Attempt 1 for FK: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.FK.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for FR...
# Attempt 1 for FR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.FR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for FO...
# Attempt 1 for FO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.FO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for FM...
# Attempt 1 for FM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.FM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GA...
# Attempt 1 for GA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GB...
# Attempt 1 for GB: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GB.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GE...
# Attempt 1 for GE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GG...
# Attempt 1 for GG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for GG: 'Series'
# No data returned (or could not retrieve) for GG.
#
# Fetching data for GH...
# Attempt 1 for GH: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GH.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GI...
# Attempt 1 for GI: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GI.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GN...
# Attempt 1 for GN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GP...
# Attempt 1 for GP: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GP.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for GP: 'Series'
# No data returned (or could not retrieve) for GP.
#
# Fetching data for GM...
# Attempt 1 for GM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GW...
# Attempt 1 for GW: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GW.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GQ...
# Attempt 1 for GQ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GQ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GR...
# Attempt 1 for GR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GD...
# Attempt 1 for GD: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GD.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GL...
# Attempt 1 for GL: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GL.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GT...
# Attempt 1 for GT: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GT.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GF...
# Attempt 1 for GF: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GF.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for GF: 'Series'
# No data returned (or could not retrieve) for GF.
#
# Fetching data for GU...
# Attempt 1 for GU: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GU.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GY...
# Attempt 1 for GY: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GY.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for HK...
# Attempt 1 for HK: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.HK.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for HM...
# Attempt 1 for HM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.HM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for HM: 'Series'
# No data returned (or could not retrieve) for HM.
#
# Fetching data for HN...
# Attempt 1 for HN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.HN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for HR...
# Attempt 1 for HR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.HR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for HT...
# Attempt 1 for HT: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.HT.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for HU...
# Attempt 1 for HU: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.HU.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for ID...
# Attempt 1 for ID: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.ID.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for IM...
# Attempt 1 for IM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.IM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for IM: 'Series'
# No data returned (or could not retrieve) for IM.
#
# Fetching data for IN...
# Attempt 1 for IN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.IN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for IO...
# Attempt 1 for IO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.IO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for IO: 'Series'
# No data returned (or could not retrieve) for IO.
#
# Fetching data for IE...
# Attempt 1 for IE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.IE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for IR...
# Attempt 1 for IR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.IR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for IQ...
# Attempt 1 for IQ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.IQ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for IS...
# Attempt 1 for IS: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.IS.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for IL...
# Attempt 1 for IL: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.IL.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for IT...
# Attempt 1 for IT: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.IT.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for JM...
# Attempt 1 for JM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.JM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for JE...
# Attempt 1 for JE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.JE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for JE: 'Series'
# No data returned (or could not retrieve) for JE.
#
# Fetching data for JO...
# Attempt 1 for JO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.JO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for JP...
# Attempt 1 for JP: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.JP.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for KZ...
# Attempt 1 for KZ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KZ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for KE...
# Attempt 1 for KE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for KG...
# Attempt 1 for KG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for KH...
# Attempt 1 for KH: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KH.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for KI...
# Attempt 1 for KI: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KI.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for KN...
# Attempt 1 for KN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for KR...
# Attempt 1 for KR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for KW...
# Attempt 1 for KW: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KW.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for LA...
# Attempt 1 for LA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for LB...
# Attempt 1 for LB: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LB.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for LR...
# Attempt 1 for LR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for LY...
# Attempt 1 for LY: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LY.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for LC...
# Attempt 1 for LC: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LC.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for LI...
# Attempt 1 for LI: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LI.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for LI: 'Series'
# No data returned (or could not retrieve) for LI.
#
# Fetching data for LK...
# Attempt 1 for LK: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LK.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for LS...
# Attempt 1 for LS: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LS.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for LT...
# Attempt 1 for LT: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LT.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for LU...
# Attempt 1 for LU: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LU.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for LV...
# Attempt 1 for LV: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.LV.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MO...
# Attempt 1 for MO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MF...
# Attempt 1 for MF: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MF.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for MF: 'Series'
# No data returned (or could not retrieve) for MF.
#
# Fetching data for MA...
# Attempt 1 for MA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MC...
# Attempt 1 for MC: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MC.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for MC: 'Series'
# No data returned (or could not retrieve) for MC.
#
# Fetching data for MD...
# Attempt 1 for MD: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MD.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MG...
# Attempt 1 for MG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MV...
# Attempt 1 for MV: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MV.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MX...
# Attempt 1 for MX: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MX.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MH...
# Attempt 1 for MH: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MH.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MK...
# Attempt 1 for MK: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MK.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for ML...
# Attempt 1 for ML: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.ML.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MT...
# Attempt 1 for MT: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MT.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MM...
# Attempt 1 for MM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for ME...
# Attempt 1 for ME: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.ME.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MN...
# Attempt 1 for MN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MP...
# Attempt 1 for MP: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MP.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for MP: 'Series'
# No data returned (or could not retrieve) for MP.
#
# Fetching data for MZ...
# Attempt 1 for MZ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MZ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MR...
# Attempt 1 for MR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MS...
# Attempt 1 for MS: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MS.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MQ...
# Attempt 1 for MQ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MQ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for MQ: 'Series'
# No data returned (or could not retrieve) for MQ.
#
# Fetching data for MU...
# Attempt 1 for MU: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MU.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MW...
# Attempt 1 for MW: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MW.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for MY...
# Attempt 1 for MY: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.MY.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for YT...
# Attempt 1 for YT: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.YT.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for YT: 'Series'
# No data returned (or could not retrieve) for YT.
#
# Fetching data for NA...
# Attempt 1 for NA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for NC...
# Attempt 1 for NC: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NC.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for NE...
# Attempt 1 for NE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for NF...
# Attempt 1 for NF: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NF.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for NF: 'Series'
# No data returned (or could not retrieve) for NF.
#
# Fetching data for NG...
# Attempt 1 for NG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for NI...
# Attempt 1 for NI: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NI.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for NU...
# Attempt 1 for NU: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NU.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for NU: 'Series'
# No data returned (or could not retrieve) for NU.
#
# Fetching data for NL...
# Attempt 1 for NL: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NL.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for NO...
# Attempt 1 for NO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for NP...
# Attempt 1 for NP: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NP.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for NR...
# Attempt 1 for NR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for NZ...
# Attempt 1 for NZ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.NZ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for OM...
# Attempt 1 for OM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.OM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PK...
# Attempt 1 for PK: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PK.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PA...
# Attempt 1 for PA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PN...
# Attempt 1 for PN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for PN: 'Series'
# No data returned (or could not retrieve) for PN.
#
# Fetching data for PE...
# Attempt 1 for PE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PH...
# Attempt 1 for PH: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PH.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PW...
# Attempt 1 for PW: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PW.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PG...
# Attempt 1 for PG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PL...
# Attempt 1 for PL: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PL.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PR...
# Attempt 1 for PR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for PR: 'Series'
# No data returned (or could not retrieve) for PR.
#
# Fetching data for KP...
# Attempt 1 for KP: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.KP.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PT...
# Attempt 1 for PT: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PT.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PY...
# Attempt 1 for PY: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PY.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PS...
# Attempt 1 for PS: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PS.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PF...
# Attempt 1 for PF: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PF.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for QA...
# Attempt 1 for QA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.QA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for RE...
# Attempt 1 for RE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.RE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for RE: 'Series'
# No data returned (or could not retrieve) for RE.
#
# Fetching data for RO...
# Attempt 1 for RO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.RO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for RU...
# Attempt 1 for RU: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.RU.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for RW...
# Attempt 1 for RW: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.RW.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SA...
# Attempt 1 for SA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SD...
# Attempt 1 for SD: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SD.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SN...
# Attempt 1 for SN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SG...
# Attempt 1 for SG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for GS...
# Attempt 1 for GS: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.GS.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for GS: 'Series'
# No data returned (or could not retrieve) for GS.
#
# Fetching data for SH...
# Attempt 1 for SH: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SH.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for SH: 'Series'
# No data returned (or could not retrieve) for SH.
#
# Fetching data for SJ...
# Attempt 1 for SJ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SJ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for SJ: 'Series'
# No data returned (or could not retrieve) for SJ.
#
# Fetching data for SB...
# Attempt 1 for SB: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SB.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SL...
# Attempt 1 for SL: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SL.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SV...
# Attempt 1 for SV: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SV.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SM...
# Attempt 1 for SM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SO...
# Attempt 1 for SO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for PM...
# Attempt 1 for PM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.PM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for PM: 'Series'
# No data returned (or could not retrieve) for PM.
#
# Fetching data for RS...
# Attempt 1 for RS: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.RS.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SS...
# Attempt 1 for SS: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SS.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for ST...
# Attempt 1 for ST: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.ST.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SR...
# Attempt 1 for SR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SK...
# Attempt 1 for SK: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SK.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SI...
# Attempt 1 for SI: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SI.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SE...
# Attempt 1 for SE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SZ...
# Attempt 1 for SZ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SZ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SX...
# Attempt 1 for SX: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SX.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SC...
# Attempt 1 for SC: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SC.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for SY...
# Attempt 1 for SY: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.SY.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TC...
# Attempt 1 for TC: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TC.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for TC: 'Series'
# No data returned (or could not retrieve) for TC.
#
# Fetching data for TD...
# Attempt 1 for TD: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TD.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TG...
# Attempt 1 for TG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TH...
# Attempt 1 for TH: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TH.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TJ...
# Attempt 1 for TJ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TJ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TK...
# Attempt 1 for TK: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TK.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for TK: 'Series'
# No data returned (or could not retrieve) for TK.
#
# Fetching data for TM...
# Attempt 1 for TM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TL...
# Attempt 1 for TL: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TL.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TO...
# Attempt 1 for TO: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TO.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TT...
# Attempt 1 for TT: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TT.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TN...
# Attempt 1 for TN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TR...
# Attempt 1 for TR: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TR.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TV...
# Attempt 1 for TV: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TV.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for TW...
# Attempt 1 for TW: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TW.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for TW: 'Series'
# No data returned (or could not retrieve) for TW.
#
# Fetching data for TZ...
# Attempt 1 for TZ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.TZ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for UG...
# Attempt 1 for UG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.UG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for UA...
# Attempt 1 for UA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.UA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for UM...
# Attempt 1 for UM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.UM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for UM: 'Series'
# No data returned (or could not retrieve) for UM.
#
# Fetching data for UY...
# Attempt 1 for UY: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.UY.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for US...
# Attempt 1 for US: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.US.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for UZ...
# Attempt 1 for UZ: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.UZ.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for VA...
# Attempt 1 for VA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.VA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for VC...
# Attempt 1 for VC: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.VC.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for VE...
# Attempt 1 for VE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.VE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for VG...
# Attempt 1 for VG: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.VG.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for VG: 'Series'
# No data returned (or could not retrieve) for VG.
#
# Fetching data for VI...
# Attempt 1 for VI: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.VI.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for VI: 'Series'
# No data returned (or could not retrieve) for VI.
#
# Fetching data for VN...
# Attempt 1 for VN: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.VN.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for VU...
# Attempt 1 for VU: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.VU.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for WF...
# Attempt 1 for WF: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.WF.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# JSON structure error (missing keys) for WF: 'Series'
# No data returned (or could not retrieve) for WF.
#
# Fetching data for WS...
# Attempt 1 for WS: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.WS.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for YE...
# Attempt 1 for YE: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.YE.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for ZA...
# Attempt 1 for ZA: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.ZA.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for ZM...
# Attempt 1 for ZM: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.ZM.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
#
# Fetching data for ZW...
# Attempt 1 for ZW: http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/DOT/Q.ZW.TXG_FOB_USD?startPeriod=1980&endPeriod=2024
# /var/folders/lx/q8fdr4551034g7fky5f96pvw0000gn/T/ipykernel_17554/772075442.py:166: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['time_period'] = pd.to_datetime(df['time_period'], errors='coerce')
